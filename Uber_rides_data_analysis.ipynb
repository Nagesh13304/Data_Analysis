# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagesh13304/Data_Analysis/blob/main/Uber_rides_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Uber Rides Data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('UberDataset.csv')
df.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %% [markdown]
# #Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#Handling Nan values in PURPOSE column
df["PURPOSE"].isnull().sum()
df["PURPOSE"] = df["PURPOSE"].fillna("Unknown")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#Drop Nan values
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     1155 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 72.2+ KB

# %%
#Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
#reset the index
df.reset_index(inplace=True)
df = df.drop("index",axis=1)
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1149   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1150  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1151  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1152  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1153  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# 1          Fort Pierce    5.0          Unknown
# 2          Fort Pierce    4.8  Errand/Supplies
# 3          Fort Pierce    4.7          Meeting
# 4      West Palm Beach   63.7   Customer Visit
# ...                ...    ...              ...
# 1149           Kar?chi    0.7          Meeting
# 1150  Unknown Location    3.9   Temporary Site
# 1151  Unknown Location   16.2          Meeting
# 1152           Gampaha    6.4   Temporary Site
# 1153         Ilukwatta   48.2   Temporary Site
#
# [1154 rows x 7 columns]

# %%
#Handling START column
df["START"] = df["START"].str.replace("R?walpindi","Rawalpindi")
df["START"] = df["START"].str.replace("Kar?chi","Karachi")
df["START"].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'Rawalpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
#        'North Austin', 'Coxville', 'Convention Center District', 'Austin',
#        'Katy', 'Sharpstown', 'Sugar Land', 'Galveston', 'Port Bolivar',
#        'Washington Avenue', 'Briar Meadow', 'Latta', 'Jacksonville',
#        'Couples Glen', 'Kissimmee', 'Lake Reams', 'Orlando',
#        'Sand Lake Commons', 'Sky Lake', 'Daytona Beach', 'Ridgeland',
#        'Florence', 'Meredith', 'Holly Springs', 'Chessington', 'Burtrose',
#        'Parkway', 'Mcvan', 'Capitol One', 'University District',
#        'Seattle', 'Redmond', 'Bellevue', 'San Francisco', 'Palo Alto',
#        'Sunnyvale', 'Newark', 'Menlo Park', 'Old City', 'Savon Height',
#        'Kilarney Woods', 'Townes at Everett Crossing', 'Huntington Woods',
#        'Seaport', 'Medical Centre', 'Rose Hill', 'Soho', 'Tribeca',
#        'Financial District', 'Oakland', 'Emeryville', 'Berkeley',
#        'Kenner', 'CBD', 'Lower Garden District', 'Lakeview', 'Storyville',
#        'New Orleans', 'Metairie', 'Chalmette', 'Arabi',
#        'Pontchartrain Shores', 'Marigny', 'Covington', 'Mandeville',
#        'Jamestown Court', 'Summerwinds', 'Parkwood',
#        'Pontchartrain Beach', 'St Thomas', 'Banner Elk', 'Elk Park',
#        'Newland', 'Boone', 'Stonewater', 'Lexington Park at Amberly',
#        'Arlington Park at Amberly', 'Arlington', 'Kalorama Triangle',
#        'K Street', 'West End', 'Connecticut Avenue', 'Columbia Heights',
#        'Washington', 'Wake Forest', 'Lahore', 'Karachi', 'SOMISSPO',
#        'West Berkeley', 'North Berkeley Hills', 'San Jose', 'Eagle Rock',
#        'Winston Salem', 'Asheville', 'Topton', 'Hayesville',
#        'Bryson City', 'Almond', 'Mebane', 'Agnew', 'Cory', 'Renaissance',
#        'Santa Clara', 'NOMA', 'Sunnyside', 'Ingleside', 'Central',
#        'Tenderloin', 'College Avenue', 'South', 'Southside',
#        'South Berkeley', 'Mountain View', 'El Cerrito', 'Krendle Woods',
#        'Wake Co.', 'Fuquay-Varina', 'Katunayake', 'Gampaha'], dtype=object)

# %%
#Handling STOP column
df["STOP"] = df["STOP"].str.replace("R?walpindi","Rawalpindi")
df["STOP"] = df["STOP"].str.replace("Kar?chi","Karachi")

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1149   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1150  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1151  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1152  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1153  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# 1          Fort Pierce    5.0          Unknown
# 2          Fort Pierce    4.8  Errand/Supplies
# 3          Fort Pierce    4.7          Meeting
# 4      West Palm Beach   63.7   Customer Visit
# ...                ...    ...              ...
# 1149           Karachi    0.7          Meeting
# 1150  Unknown Location    3.9   Temporary Site
# 1151  Unknown Location   16.2          Meeting
# 1152           Gampaha    6.4   Temporary Site
# 1153         Ilukwatta   48.2   Temporary Site
#
# [1154 rows x 7 columns]

# %% [markdown]
# #Feature Engineering

# %%
#Replace '/' to '-'
df["START_DATE"] = df["START_DATE"].str.replace("/","-")
df["END_DATE"] = df["END_DATE"].str.replace("/","-")

#convert to datetime datatype
df["START_DATE"] = pd.to_datetime(df["START_DATE"])
df["END_DATE"] = pd.to_datetime(df["END_DATE"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154 entries, 0 to 1153
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1154 non-null   datetime64[ns]
#  1   END_DATE    1154 non-null   datetime64[ns]
#  2   CATEGORY    1154 non-null   object
#  3   START       1154 non-null   object
#  4   STOP        1154 non-null   object
#  5   MILES       1154 non-null   float64
#  6   PURPOSE     1154 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.2+ KB

# %%
#Separate Date and Time columns
df["DATE"] = df["START_DATE"].dt.date
df["TIME"] = df["START_DATE"].dt.hour

#Time ---> Morning,Afternoon,Evening,Night
#New col --> DAY-NIGHT
#Morning --> 0 to 10
#Afternoon --> 11 to 15
#Evening --> 16 to 19
#Night --> 20 to 24
out = []
for i in df["TIME"]:
  if 0<=i<=10:
    out.append("Morning")
  elif 11<=i<=15:
    out.append("Afternoon")
  elif 16<=i<=19:
    out.append("Evening")
  else:
    out.append("Night")
df['DAY-NIGHT'] = out

# %%
#create DAY column
df["DAY"] = df["START_DATE"].dt.weekday
d = {0:"Mon",1:"Tue",2:"Wed",3:"Thu",4:"Fri",5:"Sat",6:"Sun"}
df["DAY"] = df["DAY"].map(d)
df
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1149 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Karachi
# 1150 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Karachi
# 1151 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1152 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1153 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE        DATE  TIME  DAY-NIGHT  \
# 0          Fort Pierce    5.1   Meal/Entertain  2016-01-01    21      Night
# 1          Fort Pierce    5.0          Unknown  2016-01-02     1    Morning
# 2          Fort Pierce    4.8  Errand/Supplies  2016-01-02    20      Night
# 3          Fort Pierce    4.7          Meeting  2016-01-05    17    Evening
# 4      West Palm Beach   63.7   Customer Visit  2016-01-06    14  Afternoon
# ...                ...    ...              ...         ...   ...        ...
# 1149           Karachi    0.7          Meeting  2016-12-31     1    Morning
# 1150  Unknown Location    3.9   Temporary Site  2016-12-31    13  Afternoon
# 1151  Unknown Location   16.2          Meeting  2016-12-31    15  Afternoon
# 1152           Gampaha    6.4   Temporary Site  2016-12-31    21      Night
# 1153         Ilukwatta   48.2   Temporary Site  2016-12-31    22      Night
#
#       DAY
# 0     Fri
# 1     Sat
# 2     Sat
# 3     Tue
# 4     Wed
# ...   ...
# 1149  Sat
# 1150  Sat
# 1151  Sat
# 1152  Sat
# 1153  Sat
#
# [1154 rows x 11 columns]

# %%
#create Month column
df["MONTH"] = df["START_DATE"].dt.month
d = {1:"Jan",  2:"Feb",  3:"Mar",  4:"Apr",  5:"May",  6:"Jun",  7:"Jul",  8:"Aug",  9:"Sep", 10:"Oct", 11:"Nov", 12:"Dec"}
df["MONTH"] = df["MONTH"].map(d)

# %% [markdown]
# #Data visualization

# %%
#save cleaned data
df.to_csv("cleaned_uber_data.csv")

# %%
def data_label(a):
  for i in a.containers:
    a.bar_label(i)

# %%
#count by CATEGORY
a = sns.countplot(x="CATEGORY",data=df,hue="CATEGORY",palette=["black","gray"],width=0.5)
plt.title("count by category",color="red")
data_label(a)

# %% [markdown]
# **Most of the rides has booked for business category than personal.**

# %%
#count by START
plt.figure(figsize=(10,6))
data = df["START"].value_counts()
data = pd.DataFrame(data[data>50]).reset_index()
a = sns.barplot(x="START",y="count",data=data,width=0.3,color='black')
plt.title("count by Start Location",color='red')
data_label(a)

# %% [markdown]
# **Most of the bookings are from cary compared to other locations**

# %%
#Distribution of MILES
sns.histplot(x="MILES",data=df[df["MILES"]<50],color='gray')
plt.title("Distribution of Miles")
plt.show()

# %% [markdown]
# **Most of the rides are for 0 to 20 miles.**
#
# **Rides count is negligible from more than 20 miles.**

# %%
#count by PURPOSE
plt.figure(figsize=(10,6))

a = sns.countplot(x="PURPOSE",data=df,width=0.3,color='black')
plt.title("count by PURPOSE",color='red')
plt.xticks(rotation=45)
data_label(a)

# %% [markdown]
# **People are liking to book the rides for Meal/Entertain,Errand/Supplies,meetings,customer visits.**

# %%
#count by PURPOSE
a = sns.countplot(x="DAY-NIGHT",data=df,width=0.3,color='black')
plt.title("count by Day-night",color='red')
data_label(a)

# %% [markdown]
# **Most of the bookings are at Afternoon and Evening**

# %%
#count by Day
a = sns.countplot(x="DAY",data=df,width=0.3,color='black')
plt.title("count by Day",color='red')
data_label(a)

# %% [markdown]
# **Most of the bookings are on Fri,Sat,Mon**

# %%
#count by Month
a = sns.countplot(x="MONTH",data=df,width=0.3,color='black')
plt.title("count by Month",color='red')
data_label(a)

# %% [markdown]
# **Most of the bookings are in Dec,Nov,Aug**
